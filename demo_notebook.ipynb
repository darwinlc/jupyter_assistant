# %% [markdown]
# # 🤖 AI Jupyter Assistant – Demo Notebook
# **`ai_jupyter.py` must be in the same folder as this notebook (or on PYTHONPATH).**

# %%
# ─── STEP 1: Load the extension (do this once per session) ───────────────
# %load_ext ai_jupyter

# %%
# ─── STEP 2: Configure (reads OPENAI_API_KEY env var, or prompts you) ────
# Optional: pass a different model or key
#   %ai_setup gpt-4o sk-...
# %ai_setup

# %% [markdown]
# ---
# ## ▶  Feature 1 – Code Completion  (`%%ai_complete`)

# %%
# %%ai_complete
# import pandas as pd
#
# def clean_dataframe(df: pd.DataFrame) -> pd.DataFrame:
#     """
#     Clean a raw DataFrame:
#     - strip whitespace from string columns
#     - drop fully-duplicate rows
#     - convert columns named *_date to datetime
#     - reset the index
#     """
#     pass

# %% [markdown]
# ---
# ## ✏  Feature 2 – Targeted Code Edit  (`%%ai_edit`)

# %%
# %%ai_edit add type hints, a docstring, and proper error handling
# def divide(a, b):
#     return a / b

# %%
# %%ai_edit convert the loop to a list comprehension and vectorise with numpy
# import numpy as np
#
# def square_evens(numbers):
#     result = []
#     for n in numbers:
#         if n % 2 == 0:
#             result.append(n ** 2)
#     return result

# %% [markdown]
# ---
# ## 🔍  Feature 3 – Code Review  (`%%ai_review`)

# %%
# %%ai_review
# import sqlite3
#
# def get_user(username):
#     conn = sqlite3.connect('users.db')
#     cur = conn.cursor()
#     cur.execute(f"SELECT * FROM users WHERE name = '{username}'")
#     return cur.fetchall()

# %% [markdown]
# ---
# ## 💬  Feature 4 – Quick Q&A  (`%ai_ask`)

# %%
# %ai_ask How do I merge two DataFrames on multiple keys keeping only matching rows?

# %%
# %ai_ask What is the difference between __repr__ and __str__ in Python?

# %% [markdown]
# ---
# ## ⚙  Feature 5 – Config  (`%ai_config`)

# %%
# Show current settings
# %ai_config

# Switch to a cheaper model for quick questions
# %ai_config model=gpt-4o-mini temperature=0.0

# Switch back for complex completions
# %ai_config model=gpt-4o temperature=0.2
